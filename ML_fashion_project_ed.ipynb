# %% [markdown]
# <a href="https://colab.research.google.com/github/ArtemStet/Data-analysis-projects/blob/main/ML_fashion_project_ed.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import libraries

import numpy as np
import random
import matplotlib.pyplot as plt
from tensorflow import keras
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras import utils

# %%
# divide dataset on traint and test parts

(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()
# Out:
# ...
# 4431872/4422102 [==============================] - 0s 0us/step

# %%
class_names = ['T-shirts', 'Trousers', 'Pullovers', 'Dresses', 'Coats', 'Sandals', 'Shirts', 'Sneakers', 'Bags', 'Ankle boots']

# %%
plt.figure(figsize=(12,10))
for i in range(1, 4):
  plt.subplot(1, 3, i)
  im = plt.imshow(x_train[i])
  plt.colorbar(im,fraction=0.046, pad=0.04)
  plt.tight_layout()

# %%
#normalisation 
x_train = x_train / 255
y_train = y_train / 255

# %%
plt.figure(figsize=(12,10))
for i in range(1, 4):
  plt.subplot(1, 3, i)
  im = plt.imshow(x_train[i])
  plt.colorbar(im,fraction=0.046, pad=0.04)
  plt.tight_layout()
