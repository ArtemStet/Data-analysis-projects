# %% [markdown]
# <a href="https://colab.research.google.com/github/ArtemStet/Data-analysis-projects/blob/main/ML_project_ed.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import libraries

import numpy as np
import random
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow import keras
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras import utils

# %%
# divide dataset on traint and test parts

(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()
# Out:
# ...
# 4431872/4422102 [==============================] - 0s 0us/step

# %%
class_names = ['T-shirt', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
plt.figure(figsize=(12,10))
for i in range(1, 4):
  plt.subplot(1, 3, i)
  im = plt.imshow(x_train[i])
  plt.colorbar(im,fraction=0.046, pad=0.04)
  plt.tight_layout()

# %%
#normalisation 
x_train = x_train / 255
x_test = x_test / 255

# %%
plt.figure(figsize=(12,10))
for i in range(1, 4):
  plt.subplot(1, 3, i)
  im = plt.imshow(x_train[i])
  plt.colorbar(im,fraction=0.046, pad=0.04)
  plt.tight_layout()

# %%
plt.figure(figsize=(10,10))
for i in range(25):
  plt.subplot(5,5, i+1)
  plt.xticks([])
  plt.yticks([])
  plt.imshow(x_train[i])
  plt.xlabel(class_names[y_train[i]])

# %%
model = keras.Sequential([keras.layers.Flatten(input_shape = (28, 28)),
                          keras.layers.Dense(128, activation='relu'),
                          keras.layers.Dense(10, activation='softmax')])

# %%
model.compile(optimizer=tf.keras.optimizers.SGD(), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  flatten_1 (Flatten)         (None, 784)               0
#
#  dense_1 (Dense)             (None, 128)               100480
#
#  dense_2 (Dense)             (None, 10)                1290
#
# ...
# Total params: 101,770
# Trainable params: 101,770
# Non-trainable params: 0
# _________________________________________________________________

# %%
#training model
model.fit(x_train, y_train, epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.7452 - accuracy: 0.7599
# Epoch 2/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.5134 - accuracy: 0.8269
# Epoch 3/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.4698 - accuracy: 0.8375
# Epoch 4/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.4455 - accuracy: 0.8477
# Epoch 5/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.4270 - accuracy: 0.8522
# Epoch 6/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.4134 - accuracy: 0.8573
# Epoch 7/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.4028 - accuracy: 0.8606
# Epoch 8/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3929 - accuracy: 0.8637
# Epoch 9/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3846 - accuracy: 0.8669
# Epoch 10/10
# ...

# %%
#accuracy check
test_loss, test_acc = model.evaluate(x_test, y_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.4270 - accuracy: 0.8472

# %%
#predict
predictions = model.predict(x_train)

# %%
predictions[0]
# Out:
# array([9.8634798e-09, 1.3258966e-09, 9.5597164e-10, 1.3906518e-09,
#        8.2777746e-10, 1.3792925e-04, 1.7176854e-08, 5.0735823e-04,
#        1.1979462e-05, 9.9934262e-01], dtype=float32)
